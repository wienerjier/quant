# %%
import pandas as pd
df = pd.read_csv('/home/wieneralan/software/quant/hs300_stocks_10000_after1year.csv',encoding='gbk')
df['cash'].sum()
# Out:
# 5763330.13

# %%
df['cash'].plot(kind='bar')
print(df)
# Out:
#       stock_id   name       cash
# 0    sz.000001   平安银行  17725.736
# 1    sz.000002    万科A  22040.384
# 2    sz.000063   中兴通讯  19841.608
# 3    sz.000069   华侨城A  19420.556
# 4    sz.000100  TCL科技  19896.590
# ..         ...    ...        ...
# 287  sh.688363   华熙生物  17628.952
# 288  sh.688396    华润微  26632.970
# 289  sh.688561    奇安信  18266.040
# 290  sh.688599   天合光能  25087.150
# 291  sh.688981   中芯国际  18334.482
#
# [292 rows x 3 columns]
